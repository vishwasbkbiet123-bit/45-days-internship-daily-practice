# %%
""" 1. Create a tuple:
my_tuple = (10, 20, 30, 40, 50)
Print:
● First element
● Last element
● Length of the tuple
● Elements from index 1 to 3
"""

my_tuple = (10,20,30,40,50)

print(my_tuple[0])  # first element
print(my_tuple[-1]) # last element
print(len(my_tuple))  # length of the tuple using len() function
print(my_tuple[1:3])  # tuple slicing
# Out:
# 10
# 50
# 5
# (20, 30)

# %%
""" 
2. Create a tuple:
fruits = ("apple", "banana", "mango", "orange")
Print:
● Second fruit
● Last two fruits
● Total number of fruits
"""
fruits = ("apple", "banana", "mango", "orange")
print(fruits[1]) # tuple indexing
print(fruits[::-2]) # negative slicing
print(len(fruits))
# Out:
# banana
# ('orange', 'banana')
# 4

# %%
""" 
3. Create a set:
numbers = {10, 20, 30, 40, 50}
Print:
● Complete set
● Length of the set
● Check whether 30 is present in the set
"""
numbers = {10, 20, 30, 40, 50}

print(numbers)
print(len(numbers))

if 30 in numbers:
    print("yes, 30 is present in numbers")
# Out:
# {50, 20, 40, 10, 30}
# 5
# yes, 30 is present in numbers

# %%
""" 4. Create two sets:
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}
Find:
● Union
● Intersection
"""
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}
uni =  set1.union(set2)
print(f"union :{uni}")

inte = set1.intersection(set2)
print(f"Intersection :{inte}")
# Out:
# union :{1, 2, 3, 4, 5, 6}
# Intersection :{3, 4}

# %%
""" 5.1. Create a dictionary:
student = {"name":"Kriti", "age":20, "course":"Python"}
Print:
● Complete dictionary
● Student name
● Student age
"""
student = {"name":"Kriti", "age":20, "course":"Python"}
print(student)
print(student["name"])
print(student["age"])
# Out:
# {'name': 'Kriti', 'age': 20, 'course': 'Python'}
# Kriti
# 20

# %%
"""
 5.2. Student course Create a list:
numbers = [12, 45, 7, 23, 56, 89, 34]
Write a program to find:
o Largest element
o Second largest element
o Smallest element
"""
numbers = [12, 45, 7, 23, 56, 89, 34]

numbers.sort()
print(numbers)
print(numbers[-1])  # largest element
print(numbers[-2])  # second largest element
print(numbers[0])   # smallest element
# Out:
# [7, 12, 23, 34, 45, 56, 89]
# 89
# 56
# 7

# %%
""" 
6. Create a list:
arr = [10, 20, 30, 40, 50, 60]
Write a function that takes the list as input and returns the list in
reverse order without using the reverse() method
"""
arr = [10, 20, 30, 40, 50, 60]

print(arr[::-1])
# Out:
# [60, 50, 40, 30, 20, 10]

# %%
""" 7. Create a tuple:
data = (5, 10, 15, 20, 25, 30, 35)
Write a program to:
○ Count how many elements are divisible by 5
○ Find the sum of all elements
○ Find the average of the tuple
"""
data = (5, 10, 15, 20, 25, 30, 35)

count = 0
for i in data:
    if i%5==0:
        count += 1
print("count = " ,count)

sum = 0
for i in data:
    sum = sum + i
print("sum is :",sum)


average = sum/len(data)
print(average)
# Out:
# count =  7
# sum is : 140
# 20.0

# %%
""" 8. Create a dictionary:
students = {
"Aman": 78,
"Riya": 92,
"Kriti": 88,
"Rahul": 95
}
Write a program to:
○ Find the student with the highest marks
○ Find the student with the lowest marks
○ Print only the students who scored more than 85 marks
"""

students = {
    "Aman": 78,
    "Riya": 92,
    "Kriti": 88,
    "Rahul": 95
}

# Student with highest marks
highest_student = max(students, key=students.get)
print("Highest Marks:", highest_student, "->", students[highest_student])

# Student with lowest marks
lowest_student = min(students, key=students.get)
print("Lowest Marks:", lowest_student, "->", students[lowest_student])

# Students scoring more than 85 marks
print("Students scoring more than 85 marks:")
for name, marks in students.items():
    if marks > 85:
        print(name, "->", marks)
# Out:
# Highest Marks: Rahul -> 95
# Lowest Marks: Aman -> 78
# Students scoring more than 85 marks:
# Riya -> 92
# Kriti -> 88
# Rahul -> 95

# %%
""" 9. Write a function:
count_frequency(arr)
that takes a list as input and prints the frequency of each element.
Example:
arr = [1, 2, 2, 3, 1, 4, 2]
Output:
1 -> 2 times
2 -> 3 times
3 -> 1 time
4 -> 1 time
"""

arr = [1, 2, 2, 3, 1, 4, 2]
def count_frequency(arr):
    visited = []

    for item in arr:
        if item not in visited:
            count = 0

            for element in arr:
                if item == element:
                    count += 1

            if count == 1:
                print(f"{item} -> {count} time")
            else:
                print(f"{item} -> {count} times")

            visited.append(item)



count_frequency(arr)
# Out:
# 1 -> 2 times
# 2 -> 3 times
# 3 -> 1 time
# 4 -> 1 time

# %%
""" 10.Write a function:
find_duplicates(arr)
that takes a list as input and prints all duplicate elements present in
the list.
Example:
arr = [10, 20, 30, 20, 40, 10, 50, 30]
Output:
Duplicate elements are:
10
20
30
"""
def find_duplicates(arr):
    duplicates = []

    for item in arr:
        if arr.count(item) > 1 and item not in duplicates:
            duplicates.append(item)

    print("Duplicate elements are:")
    for item in duplicates:
        print(item)


arr = [10, 20, 30, 20, 40, 10, 50, 30]
find_duplicates(arr)
# Out:
# Duplicate elements are:
# 10
# 20
# 30

# %% [markdown]
# ## 👉👉👉👉👉👉😊Thank you😊👈👈👈👈👈👈
